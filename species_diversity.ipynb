# %%
import pandas as pd
import numpy as np
import folium

abundance_df = pd.read_csv('Final_Abundance_2008_2023.csv')
percent_df = pd.read_csv('Final_Percent_2009_2023.csv')

# %%
abundance_df
# Out:
#       Unnamed: 0  Sample_Point_(SP)  Year   Latitude  Longitude   Depth  \
# 0              0                  1  2008  42.977652 -75.887120  0.3048
# 1              1                  2  2008  42.977520 -75.887213  0.3048
# 2              2                  3  2008  42.977661 -75.887699  0.6096
# 3              3                  4  2008  42.977674 -75.888337  0.6096
# 4              4                  5  2008  42.977542 -75.889355  0.6096
# ...          ...                ...   ...        ...        ...     ...
# 4857         297                300  2023        NaN        NaN     NaN
# 4858         298                301  2023        NaN        NaN     NaN
# 4859         299                302  2023        NaN        NaN     NaN
# 4860         300                303  2023        NaN        NaN     NaN
# 4861         301                304  2023        NaN        NaN     NaN
#
#      Rake_Abundance  Rake_Abundance_# Alisma_gramineum  \
# ...

# %%
percent_df
# Out:
#       Unnamed: 0 Sample_Point_(SP)  Year        Date  Rake_toss_#   Latitude  \
# 0              0                 1  2009         NaN          1.0  42.977680
# 1              1                 1  2009         NaN          2.0  42.977680
# 2              2                 2  2009         NaN          1.0  42.977520
# 3              3                 2  2009         NaN          2.0  42.977520
# 4              4                 3  2009         NaN          1.0  42.977661
# ...          ...               ...   ...         ...          ...        ...
# 9113         599               302  2023  2023-08-31          2.0  42.961837
# 9114         600               303  2023  2023-08-08          1.0  42.948490
# 9115         601               303  2023  2023-08-08          2.0  42.948490
# 9116         602               304  2023  2023-08-08          1.0  42.948360
# 9117         603               304  2023  2023-08-08          2.0  42.948360
#
# ...

# %%
lake_map_2008 = folium.Map(location=[42.950253, -75.870825], zoom_start=13)
# lake_map_2008

# %%
abundance_2008 = abundance_df.loc[abundance_df.Year == 2008]
abundance_2008
# Out:
#      Unnamed: 0  Sample_Point_(SP)  Year   Latitude  Longitude   Depth  \
# 0             0                  1  2008  42.977652 -75.887120  0.3048
# 1             1                  2  2008  42.977520 -75.887213  0.3048
# 2             2                  3  2008  42.977661 -75.887699  0.6096
# 3             3                  4  2008  42.977674 -75.888337  0.6096
# 4             4                  5  2008  42.977542 -75.889355  0.6096
# ..          ...                ...   ...        ...        ...     ...
# 297         297                298  2008  42.959125 -75.870077  0.6096
# 298         298                299  2008  42.959650 -75.870627  0.9144
# 299         299                300  2008  42.960420 -75.871387  0.9144
# 300         300                301  2008  42.961219 -75.871882  0.9144
# 301         301                302  2008  42.961837 -75.872214  1.2192
#
#     Rake_Abundance  Rake_Abundance_# Alisma_gramineum  \
# 0              NaN               NaN              NaN
# ...

# %%
abundance_2008.columns
# Out:
# Index(['Unnamed: 0', 'Sample_Point_(SP)', 'Year', 'Latitude', 'Longitude',
#        'Depth', 'Rake_Abundance', 'Rake_Abundance_#', 'Alisma_gramineum',
#        'Benthic_Filamentous_Algae', 'Callitriche_hermaphroditica',
#        'Ceratophyllum_demersum', 'Chara_vulgaris', 'Elodea_sp.',
#        'Floating_Filamentous_Algae', 'Fontinalis_sp.', 'Heteranthera_dubia',
#        'Hydrocharis_morsus-ranae', 'Hypericum_ellipticum', 'Lemna_minor',
#        'Lemna_trisulca', 'Megalodonta_beckii', 'Myriophyllum_sibiricum',
#        'Myriophyllum_spicatum', 'Najas_flexilis', 'Najas_guadalupensis',
#        'Nitella_flexilis', 'Nitellopsis_obtusa', 'Nuphar_variegata',
#        'Nymphaea_odorata', 'Pithophora_sp.', 'Polygonum_amphibium',
#        'Potamogeton_amplifolius', 'Potamogeton_crispus',
#        'Potamogeton_crispus_turions', 'Potamogeton_foliosus',
#        'Potamogeton_gramineus', 'Potamogeton_illinoensis',
#        'Potamogeton_pectinatus', 'Potamogeton_praelongus',
# ...

# %%
for (index, col) in enumerate(abundance_2008.columns):
  print(index, col)
# Out:
# 0 Unnamed: 0
# 1 Sample_Point_(SP)
# 2 Year
# 3 Latitude
# 4 Longitude
# 5 Depth
# 6 Rake_Abundance
# 7 Rake_Abundance_#
# 8 Alisma_gramineum
# 9 Benthic_Filamentous_Algae
# 10 Callitriche_hermaphroditica
# 11 Ceratophyllum_demersum
# 12 Chara_vulgaris
# 13 Elodea_sp.
# 14 Floating_Filamentous_Algae
# 15 Fontinalis_sp.
# 16 Heteranthera_dubia
# 17 Hydrocharis_morsus-ranae
# 18 Hypericum_ellipticum
# 19 Lemna_minor
# 20 Lemna_trisulca
# 21 Megalodonta_beckii
# 22 Myriophyllum_sibiricum
# 23 Myriophyllum_spicatum
# 24 Najas_flexilis
# 25 Najas_guadalupensis
# 26 Nitella_flexilis
# 27 Nitellopsis_obtusa
# 28 Nuphar_variegata
# 29 Nymphaea_odorata
# 30 Pithophora_sp.
# 31 Polygonum_amphibium
# 32 Potamogeton_amplifolius
# 33 Potamogeton_crispus
# 34 Potamogeton_crispus_turions
# 35 Potamogeton_foliosus
# 36 Potamogeton_gramineus
# 37 Potamogeton_illinoensis
# 38 Potamogeton_pectinatus
# 39 Potamogeton_praelongus
# 40 Potamogeton_pusillus
# 41 Potamogeton_richardsonii
# ...

# %%
plant_names = list(abundance_2008.columns[8:])
plant_names
# Out:
# ['Alisma_gramineum',
#  'Benthic_Filamentous_Algae',
#  'Callitriche_hermaphroditica',
#  'Ceratophyllum_demersum',
#  'Chara_vulgaris',
#  'Elodea_sp.',
#  'Floating_Filamentous_Algae',
#  'Fontinalis_sp.',
#  'Heteranthera_dubia',
#  'Hydrocharis_morsus-ranae',
#  'Hypericum_ellipticum',
#  'Lemna_minor',
#  'Lemna_trisulca',
#  'Megalodonta_beckii',
#  'Myriophyllum_sibiricum',
#  'Myriophyllum_spicatum',
#  'Najas_flexilis',
#  'Najas_guadalupensis',
#  'Nitella_flexilis',
#  'Nitellopsis_obtusa',
#  'Nuphar_variegata',
#  'Nymphaea_odorata',
#  'Pithophora_sp.',
#  'Polygonum_amphibium',
#  'Potamogeton_amplifolius',
#  'Potamogeton_crispus',
#  'Potamogeton_crispus_turions',
#  'Potamogeton_foliosus',
#  'Potamogeton_gramineus',
#  'Potamogeton_illinoensis',
#  'Potamogeton_pectinatus',
#  'Potamogeton_praelongus',
#  'Potamogeton_pusillus',
#  'Potamogeton_richardsonii',
#  'Potamogeton_zosteriformis',
#  'Ranunculus_trichophyllus',
#  'Riccia_fluitans',
# ...

# %%
# none, trace, sparse, moderate, dense
scale = ['N', 'T', 'S', 'M', 'D'] # use index for number value

# %%
for plant in plant_names:
  abundance_2008[plant] = abundance_2008[plant].fillna('N')
abundance_2008
# Out:
# /var/folders/pt/0jkzh_kd059fycr5pcmnh7z40000gn/T/ipykernel_82112/2484959331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   abundance_2008[plant] = abundance_2008[plant].fillna('N')
#      Unnamed: 0  Sample_Point_(SP)  Year   Latitude  Longitude   Depth  \
# 0             0                  1  2008  42.977652 -75.887120  0.3048
# 1             1                  2  2008  42.977520 -75.887213  0.3048
# 2             2                  3  2008  42.977661 -75.887699  0.6096
# 3             3                  4  2008  42.977674 -75.888337  0.6096
# 4             4                  5  2008  42.977542 -75.889355  0.6096
# ..          ...                ...   ...        ...        ...     ...
# ...
